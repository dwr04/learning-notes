# %% [markdown]
# ## esc+M然后shift+enter可以运行markdown语法渲染

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("OK")
# Out:
# OK

# %% [markdown]
# - 右击标题选择**new view for note book**可以双视图
# - 右击输出结果选择**creat new view for output**可以只看输出结果在新窗口
# - 右击标题选择**new console for note book**可以拉出一个代码运行区块
# - new console还可以选择mark down/py文件里的代码或者部分代码来运行，具体操作方式：选择代码，shift+enter
