# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
scores=np.random.randint(60,101,(5,3))
courses=["语文","数字","英语"]
stu_id=np.arange(1001,1006)
df1=pd.DataFrame(columns=courses,index=stu_id,data=scores)
df1
# Out:
#       语文  数字  英语
# 1001  78  83  97
# 1002  65  71  97
# 1003  74  63  95
# 1004  99  80  89
# 1005  98  64  70

# %%
scores = {
    '语文': [62, 72, 93, 88, 93],
    '数学': [95, 65, 86, 66, 87],
    '英语': [66, 75, 82, 69, 82],
}
stu_ids = np.arange(1001, 1006)
df2 = pd.DataFrame(data=scores, index=stu_ids)
df2
# Out:
#       语文  数学  英语
# 1001  62  95  66
# 1002  72  65  75
# 1003  93  86  82
# 1004  88  66  69
# 1005  93  87  82

# %%
scores={
    1001: [62,95,66],
    1002: [72,65,75],
    1003: [93,86,82],
    1004: [88,66,69],
    1005: [93,87,82]
}
courses=["语文","数字","英语"]
df2=pd.DataFrame(columns=courses,data=scores)
df2#默认的是字典的索引为列columns
# Out:
# Empty DataFrame
# Columns: [语文, 数字, 英语]
# Index: []

# %%
df2 = pd.DataFrame.from_dict(scores, orient="index", columns=courses)
df2
# Out:
#       语文  数字  英语
# 1001  62  95  66
# 1002  72  65  75
# 1003  93  86  82
# 1004  88  66  69
# 1005  93  87  82

# %%
df3=pd.read_csv("2018年北京积分落户数据.csv",index_col='id')
df3
# Out:
#      name birthday              company   score
# id
# 1     杨效丰  1972-12       北京利德华福电气技术有限公司  122.59
# 2     纪丰伟  1974-12         北京航天数据股份有限公司  121.25
# 3      王永  1974-05       品牌联盟(北京)咨询股份公司  118.96
# 4      杨静  1975-07       中科专利商标代理有限责任公司  118.21
# 5     张凯江  1974-11      北京阿里巴巴云计算技术有限公司  117.79
# ...   ...      ...                  ...     ...
# 6015  孙宏波  1978-08    华为海洋网络有限公司北京科技分公司   90.75
# 6016  刘丽香  1976-11  福斯（上海）流体设备有限公司北京分公司   90.75
# 6017   周崧  1977-10      赢创德固赛（中国）投资有限公司   90.75
# 6018   赵妍  1979-07     澳科利耳医疗器械（北京）有限公司   90.75
# 6019   贺锐  1981-06           北京宝洁技术有限公司   90.75
#
# [6019 rows x 4 columns]

# %%
from IPython.display import Image, display

display(Image(filename="read_csv参数.png"))

# %%
df4=pd.read_excel("留学资料.xlsx",sheet_name="Sheet1",index_col="本科学校")
df4
# Out:
#                      专业              本科GPA 硕士院校 硕士专业 硕士GPA IELTS  \
# 本科学校
# 本科Top15              CS  91.2||3.9||Top 2%  NaN  NaN   NaN   NaN
# 本科其他985/211       uestc               3.78  NaN  NaN   NaN   NaN
# 海本                 apma                3.7  NaN  NaN   NaN   NaN
# 本科Top30            软件工程           88.9/100  NaN  NaN   NaN   NaN
# 海本           Stats+Econ           3.76/4.0  NaN  NaN   NaN   NaN
# ...                 ...                ...  ...  ...   ...   ...
# 北京航空航天大学          计算机科学                3.6  NaN  NaN   NaN   NaN
# 北京航空航天大学          计算机科学                3.6  NaN  NaN   NaN   NaN
# 北京航空航天大学          计算机科学                3.6  NaN  NaN   NaN   NaN
# 北京航空航天大学          计算机科学                3.6  NaN  NaN   NaN   NaN
# 211                  EE                2.9  NaN  NaN   NaN   NaN
#
#                                        TOEFL GMAT  \
# 本科学校
# 本科Top15                                  111  NaN
# 本科其他985/211                          100/s22  NaN
# ...

# %%
display(Image(filename="read_excel参数.png"))

# %%
import pymysql
import sqlalchemy

# %%
conn = pymysql.connect(
    host='101.42.16.8', port=3306,
    user='guest', password='Guest.618',
    database='hrs', charset='utf8mb4'
)
df5=pd.read_sql('select * from tb_emp',conn,index_col='eno')
df5
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 conn = pymysql.connect(
#       2     host='101.42.16.8', port=3306,
#       3     user='guest', password='Guest.618',
#       4     database='hrs', charset='utf8mb4'
#       5 )
#       6 df5=pd.read_sql('select * from tb_emp',conn,index_col='eno')
#       7 df5
#
# ...
